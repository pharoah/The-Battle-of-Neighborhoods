# %% [markdown]
# ##  Download and Explore New York city and its Boroughs Cuisine dataset

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
from PIL import Image # converting images into arrays
import requests
# %matplotlib inline
from bs4 import BeautifulSoup
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0

# install wordcloud
#!conda install -c conda-forge wordcloud==1.4.1 --yes

# import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS
# Out:
# Matplotlib version:  3.0.3

# %% [markdown]
# <b> This data is extracted from the wikipedia Page - https://en.wikipedia.org/wiki/Cuisine_of_New_York_City </b>

# %%
import csv
import re
website_url = requests.get('https://en.wikipedia.org/wiki/Cuisine_of_New_York_City').text
soup = BeautifulSoup(website_url,'lxml')
borough = []

headers = ['Borough', 'Neighbourhood', 'Cuisine']

soup1 = soup.find_all('li',class_='toclevel-1')[0].find_all('li')
for i in soup1:
    borough.append(''.join(i.a.text.split(' ')[1:]))
    
print(len(borough))
file = open('NYC_CUISINE.csv','w',encoding='utf-8')
writer = csv.writer(file)
writer.writerow(headers)
for i in range(len(borough)):
    for j in range(len(soup.find_all('div', class_='div-col')[i].find('ul').find_all('li'))):
        n = soup.find_all('div', class_='div-col')[i].find('ul').find_all('li')[j].a.text
        c = soup.find_all('div', class_='div-col')[i].find('ul').find_all('li')[j].text.replace(n,"")[2:]
        writer.writerow([borough[i],n,c])
file.close()
df_cuisine = pd.read_csv('NYC_CUISINE.csv')

  # writer.writerows(row for row in rows if row)
# Out:
# 5

# %%
df_cuisine.tail()
# Out:
#       Borough                   Neighbourhood   Cuisine
# 64  Manhattan                   Waldorf Salad       NaN
# 65  Manhattan                        Doughnut       NaN
# 66  Manhattan                 Delmonico steak       NaN
# 67  Manhattan          Black and white cookie       NaN
# 68  Manhattan  Bacon, egg and cheese sandwich  n a roll

# %% [markdown]
# <b> There was html format error while scraping, since error is minute we could do it manually</b>

# %%
df_cuisine.replace({'StatenIsland':'Manhattan'}, regex=True,inplace=True)
df_cuisine.tail(30)
# Out:
#       Borough                   Neighbourhood  \
# 39   Brooklyn                     Sunset Park
# 40   Brooklyn                    Williamsburg
# 41  Manhattan                       Chinatown
# 42  Manhattan                     East Harlem
# 43  Manhattan                    East Village
# 44  Manhattan               Greenwich Village
# 45  Manhattan                          Harlem
# 46  Manhattan                       Koreatown
# 47  Manhattan                    Little Italy
# 48  Manhattan                 Lower East Side
# 49  Manhattan                     Murray Hill
# 50  Manhattan              Washington Heights
# 51  Manhattan                 Upper East Side
# 52  Manhattan          Manhattan clam chowder
# 53  Manhattan       New York-style cheesecake
# 54  Manhattan            New York-style pizza
# 55  Manhattan            New York-style bagel
# 56  Manhattan         New York-style pastrami
# 57  Manhattan                     Corned beef
# 58  Manhattan                        pretzels
# 59  Manhattan      New York-style Italian ice
# 60  Manhattan                           Knish
# 61  Manhattan                   Eggs Benedict
# 62  Manhattan                  Chopped Cheese
# 63  Manhattan                 Lobster Newberg
# 64  Manhattan                   Waldorf Salad
# 65  Manhattan                        Doughnut
# 66  Manhattan                 Delmonico steak
# 67  Manhattan          Black and white cookie
# 68  Manhattan  Bacon, egg and cheese sandwich
#
#                                               Cuisine
# 39   Puerto Rican, Chinese, Arab, Mexican and Italian
# 40        Italian, Jewish, Dominican and Puerto Rican
# 41                             Chinese and Vietnamese
# 42   Puerto Rican, Mexican, Dominican, Chinese-Cub...
# 43             Japanese, Korean, Indian and Ukrainian
# 44                                            Italian
# 45   Italian, African-American, Latin American, We...
# 46                                             Korean
# 47                                            Italian
# 48   Puerto Rican, Jewish, Italian, and Latin Amer...
# 49                  Indian, Pakistani and Bangladeshi
# 50        Dominican, Puerto Rican, Italian and Jewish
# 51                           German, Czech, Hungarian
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                  ]
# 58                                               ked
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                           n a roll

# %%
df_cuisine.drop(df_cuisine.index[52:69],inplace=True)

# %%
df2 = pd.DataFrame([['StatenIsland','Port Richmond','Mexican, Indian, Italian'],['StatenIsland', 'Rossville; South Beach; Great Kills','Italian, Russian, Arab and Polish'],['StatenIsland','Tompkinsville',' Italian, Sri Lankan, Pakistani, Indian']],columns=['Borough','Neighbourhood','Cuisine'])

# %%
cuisine_final = df_cuisine.append(df2)

# %%
cuisine_final['Borough'].value_counts().to_frame()
# Out:
#               Borough
# Brooklyn           19
# Queens             13
# Manhattan          11
# TheBronx            9
# StatenIsland        3

# %% [markdown]
# ## New York City Word Count

# %%
cuisine_nyc_wc = df_cuisine[['Cuisine']]
cuisine_nyc_wc
# Out:
#                                               Cuisine
# 0    Mexican, Puerto Rican, Dominican, Korean (on ...
# 1    Italian, Albanian (also known as "Arthur Aven...
# 2                                    Italian, Seafood
# 3                                   Italian, Albanian
# 4            Filipino (formerly Irish, less so today)
# 5                                              Jewish
# 6                             Puerto Rican, Dominican
# 7                               Jamaican, West Indian
# 8                                               Irish
# 9    Greek, Italian, Eastern European, Brazilian, ...
# 10                               Indian and Pakistani
# 11                                 Chinese and Korean
# 12  Kew Gardens Hills; Rego Park – Jewish, Russian...
# 13                               Ozone Park – Italian
# 14                                  German and Polish
# 15   Indian, Pakistani, Bangladeshi, Colombian, Ec...
# 16   Bangladeshi, Caribbean; African-American; Afr...
# 17                         Arab, Chinese, and Italian
# 18   Indian, Guyanese, West Indian, Pakistani, Ban...
# 19                                      Irish, Jewish
# 20                Irish, Dominican, Mexican, Guyanese
# 21  Sunnyside – Filipino, Irish, Mexican, and Roma...
# 22   Irish, Italian, Greek, Turkish, Lebanese, Pal...
# 23   African-American, Jamaican, Trinidadian, Puer...
# 24  – Italian, Chinese, Turkish, Russian, Mexican,...
# 25                  Jewish, Italian, Mexican, Chinese
# 26   Russian, Georgian, Turkish, Pakistani and Ukr...
# 27   Puerto Rican, Mexican, Dominican, and Ecuadorian
# 28            Jamaican, West Indian, African-American
# 29                                            Italian
# 30                  Jamaican, West Indian, and Jewish
# 31      African-American, Dominican, and Puerto Rican
# 32                      Jamaican, Haitian, and Creole
# 33                               Polish and Ukrainian
# 34     Bengali, Pakistani, Mexican, Uzbek, and Polish
# 35            Jewish, Italian, Russian, and Pakistani
# 36   Italian, Irish, French, and Puerto Rican (for...
# 37        Puerto Rican, African-American, and Italian
# 38                      Seafood, Russian, and Italian
# 39   Puerto Rican, Chinese, Arab, Mexican and Italian
# 40        Italian, Jewish, Dominican and Puerto Rican
# 41                             Chinese and Vietnamese
# 42   Puerto Rican, Mexican, Dominican, Chinese-Cub...
# 43             Japanese, Korean, Indian and Ukrainian
# 44                                            Italian
# 45   Italian, African-American, Latin American, We...
# 46                                             Korean
# 47                                            Italian
# 48   Puerto Rican, Jewish, Italian, and Latin Amer...
# 49                  Indian, Pakistani and Bangladeshi
# 50        Dominican, Puerto Rican, Italian and Jewish
# 51                           German, Czech, Hungarian

# %%
cuisine_nyc_wc.to_csv('cuisine_nyc_wc.txt', sep=',', index=False)

# %%
cuisine_wc = open('cuisine_nyc_wc.txt', 'r').read()

# %%
stopwords = set(STOPWORDS)

# %%
# instantiate a word cloud object
NYC_WC = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
NYC_WC.generate(cuisine_wc)

# %%
# display the word cloud
plt.imshow(NYC_WC, interpolation='bilinear')
plt.axis('off')

fig = plt.figure()
fig.set_figwidth(30)
fig.set_figheight(45)

plt.show()

# %% [markdown]
# Most Preferred Food in New York City -
#
#     Italian
#     Purto Rican
#     Mexican
#     Jewish
#     Indian
#     Pakistani
#     Dominican

# %% [markdown]
# ## BROOKLYN CUISINE - WORD CLOUD

# %%
Brooklyn_data = cuisine_final[cuisine_final['Borough'] == 'Brooklyn'].reset_index(drop=True)
Brooklyn_data.head()
# Out:
#     Borough       Neighbourhood  \
# 0  Brooklyn           Bay Ridge
# 1  Brooklyn  Bedford-Stuyvesant
# 2  Brooklyn         Bensonhurst
# 3  Brooklyn        Borough Park
# 4  Brooklyn      Brighton Beach
#
#                                              Cuisine
# 0   Irish, Italian, Greek, Turkish, Lebanese, Pal...
# 1   African-American, Jamaican, Trinidadian, Puer...
# 2  – Italian, Chinese, Turkish, Russian, Mexican,...
# 3                  Jewish, Italian, Mexican, Chinese
# 4   Russian, Georgian, Turkish, Pakistani and Ukr...

# %%
cuisine_br_wc = Brooklyn_data[['Cuisine']]
cuisine_br_wc
# Out:
#                                               Cuisine
# 0    Irish, Italian, Greek, Turkish, Lebanese, Pal...
# 1    African-American, Jamaican, Trinidadian, Puer...
# 2   – Italian, Chinese, Turkish, Russian, Mexican,...
# 3                   Jewish, Italian, Mexican, Chinese
# 4    Russian, Georgian, Turkish, Pakistani and Ukr...
# 5    Puerto Rican, Mexican, Dominican, and Ecuadorian
# 6             Jamaican, West Indian, African-American
# 7                                             Italian
# 8                   Jamaican, West Indian, and Jewish
# 9       African-American, Dominican, and Puerto Rican
# 10                      Jamaican, Haitian, and Creole
# 11                               Polish and Ukrainian
# 12     Bengali, Pakistani, Mexican, Uzbek, and Polish
# 13            Jewish, Italian, Russian, and Pakistani
# 14   Italian, Irish, French, and Puerto Rican (for...
# 15        Puerto Rican, African-American, and Italian
# 16                      Seafood, Russian, and Italian
# 17   Puerto Rican, Chinese, Arab, Mexican and Italian
# 18        Italian, Jewish, Dominican and Puerto Rican

# %%
cuisine_br_wc.to_csv('cuisine_br_wc.txt', sep=',', index=False)

# %%
cuisine_br = open('cuisine_br_wc.txt', 'r').read()

# %%
stopwords = set(STOPWORDS)

# %%
# instantiate a word cloud object
BR_NYC = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
BR_NYC.generate(cuisine_br)

# display the word cloud
plt.imshow(BR_NYC, interpolation='bilinear')
plt.axis('off')

fig = plt.figure()
fig.set_figwidth(30)
fig.set_figheight(45)

plt.show()

# %% [markdown]
# Most Preferred Food in Brooklyn is -
#
#     Italian
#     Purto Rican
#     Mexican

# %% [markdown]
# ## QUEENS CUISINE - WORD CLOUD

# %%
Queens_data = df_cuisine[df_cuisine['Borough'] == 'Queens'].reset_index(drop=True)
Queens_data.head()
# Out:
#   Borough Neighbourhood                                            Cuisine
# 0  Queens       Astoria   Greek, Italian, Eastern European, Brazilian, ...
# 1  Queens     Bellerose                               Indian and Pakistani
# 2  Queens      Flushing                                 Chinese and Korean
# 3  Queens  Forest Hills  Kew Gardens Hills; Rego Park – Jewish, Russian...
# 4  Queens  Howard Beach                               Ozone Park – Italian

# %%
cuisine_q_wc = Queens_data[['Cuisine']]
cuisine_q_wc
# Out:
#                                               Cuisine
# 0    Greek, Italian, Eastern European, Brazilian, ...
# 1                                Indian and Pakistani
# 2                                  Chinese and Korean
# 3   Kew Gardens Hills; Rego Park – Jewish, Russian...
# 4                                Ozone Park – Italian
# 5                                   German and Polish
# 6    Indian, Pakistani, Bangladeshi, Colombian, Ec...
# 7    Bangladeshi, Caribbean; African-American; Afr...
# 8                          Arab, Chinese, and Italian
# 9    Indian, Guyanese, West Indian, Pakistani, Ban...
# 10                                      Irish, Jewish
# 11                Irish, Dominican, Mexican, Guyanese
# 12  Sunnyside – Filipino, Irish, Mexican, and Roma...

# %%
cuisine_q_wc.to_csv('Queens_WC.txt', sep=',', index=False)
queens_wc = open('Queens_WC.txt', 'r').read()
stopwords = set(STOPWORDS)

# %%
# instantiate a word cloud object
Q_NYC = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
Q_NYC.generate(queens_wc)

# display the word cloud
plt.imshow(Q_NYC, interpolation='bilinear')
plt.axis('off')

fig = plt.figure()
fig.set_figwidth(30)
fig.set_figheight(45)

plt.show()

# %% [markdown]
# Most Preferred Food in Queens is -
#
#     Indian
#     Italian
#     Pakistani
#     Mexican

# %% [markdown]
# ## Manhattan Word Cloud

# %%
Man_data = df_cuisine[df_cuisine['Borough'] == 'Manhattan'].reset_index(drop=True)
cuisine_man_wc = Man_data['Cuisine']
cuisine_man_wc.to_csv('M_C.txt', sep=',', index=False)
M_WC = open('M_C.txt', 'r').read()
M_WC = open('M_C.txt', 'r').read()
stopwords = set(STOPWORDS)

# instantiate a word cloud object
M_NYC = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
M_NYC.generate(M_WC)

# display the word cloud
plt.imshow(M_NYC, interpolation='bilinear')
plt.axis('off')

fig = plt.figure()
fig.set_figwidth(30)
fig.set_figheight(45)

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# Most Preferred Food in Manhattan is -
#
#     Italian
#     Indian
#     American
#     Puerto Rican

# %% [markdown]
# ## THE BRONX CUISINE - WORD CLOUD

# %%
TBR_data = df_cuisine[df_cuisine['Borough'] == 'TheBronx'].reset_index(drop=True)
cuisine_tbr_wc = TBR_data['Cuisine']
cuisine_tbr_wc.to_csv('B_C.txt', sep=',', index=False)
TBR_WC = open('B_C.txt', 'r').read()
TBR_WC = open('B_C.txt', 'r').read()
stopwords = set(STOPWORDS)

# instantiate a word cloud object
TBR_NYC = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
TBR_NYC.generate(TBR_WC)

# display the word cloud
plt.imshow(TBR_NYC, interpolation='bilinear')
plt.axis('off')

fig = plt.figure()
fig.set_figwidth(30)
fig.set_figheight(45)

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# Most Preferred Food in The Bronx is -
#
#     Italian
#     Puerto
#     Albanian
#     Dominican
